# %%
import gym
import numpy as np
import pickle
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from tensorboardX import SummaryWriter
from collections import deque
import numpy as np
np.random.seed(42)  # You can choose any number for the seed

# %%
import gym
import numpy as np

class ASACRLEnv(gym.Env):
    def __init__(self, observations, actions, action_parameter, action_space, num_intervals):
        """initialize action space, observation space & load data"""
        self.action_parameter = action_parameter
        self.num_intervals = num_intervals
        self.action_space = gym.spaces.Box(low=action_space[0], high=action_space[1], dtype=np.float32)
        self.observations = observations
        self.actions = actions
        self.index = 0
        self.teamindex = 0
        obs_min = np.min(np.concatenate(self.observations), axis=0)
        obs_max = np.max(np.concatenate(self.observations), axis=0)

        self.observation_space = gym.spaces.Box(
            low=obs_min,
            high=obs_max,
            dtype=np.float32
        )

        self.curr_obs = self.observations[self.teamindex].iloc[self.index]
        self.next_obs = self.curr_obs = self.observations[self.teamindex].iloc[self.index + 1]
        self.curr_reward = 0
        self.ep_reward = 0
        self.interval = (self.action_space.high[0] - self.action_space.low[0]) / self.num_intervals

    def step(self, action):
        chosen_action = self.map_continuous_to_interval(action)
        self.reward = self.rewardfunc(chosen_action)
        self.ep_reward += self.reward
        self.index += 1
        done = False  # Set done to False by default

        if self.index >= len(self.observations[self.teamindex]) - 2:
            self.reset()
            done = True  # Set done to True when the episode is finished
            return self.curr_obs, self.reward, done, {}  # Return the additional info as an empty dictionary

        self.curr_obs = self.observations[self.teamindex].iloc[self.index]
        self.next_obs = self.observations[self.teamindex].iloc[self.index + 1]
        return self.curr_obs, self.reward, done, {}

    def map_continuous_to_interval(self, action):
        interval_width = (self.action_space.high - self.action_space.low) / self.num_intervals
        discrete_action = int((action - self.action_space.low) / interval_width)
        return discrete_action * interval_width + self.action_space.low

    def rewardfunc(self, action):
        if action == self.estimate_closest_as(self.actions[self.teamindex][self.action_parameter][self.index]):
            return 1000
        else:
            return -1 * abs(action - self.estimate_closest_as(self.actions[self.teamindex][self.action_parameter][self.index]))


    def estimate_closest_as(self, value):
        try:
            closest_action_index = int(value / self.interval)
            max_index = int((self.action_space.high[0] - self.action_space.low[0]) / self.interval)
            closest_action_index = min(closest_action_index, max_index)
        except ValueError:
            closest_action_index = max_index
        return closest_action_index
    # def estimate_closest_as(self, value):
    #     try:
    #         closest_action_index = int(value / self.interval)
    #         closest_action_index = min(closest_action_index, self.action_space.n - 1)
    #     except:
    #         closest_action_index = self.action_space.n - 1
    #     return closest_action_index


    def reset(self):
        self.teamindex += 1
        if self.teamindex >= 5:
            self.teamindex = 0
        self.index = 0
        self.curr_obs = self.observations[self.teamindex].iloc[self.index]
        self.next_obs = self.observations[self.teamindex].iloc[self.index + 1]
        self.curr_reward = 0
        self.ep_reward = 0
        return self.curr_obs

# %%
with open('/Users/faymajidelhassan/Downloads/ASAC_2023/observations.pickle', 'rb') as handle:
    obs = pickle.load(handle)
with open('/Users/faymajidelhassan/Downloads/ASAC_2023/actions.pickle', 'rb') as handle:
    actions = pickle.load(handle)

# %%
# !pip install shimmy
# !pip install gymnasium
# !pip install stable_baselines3
# !pip install tensorboard
# Out:
# Requirement already satisfied: shimmy in /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.18.0 in /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages (from shimmy) (1.23.5)
# Requirement already satisfied: gymnasium>=0.27.0 in /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages (from shimmy) (0.28.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages (from gymnasium>=0.27.0->shimmy) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages (from gymnasium>=0.27.0->shimmy) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages (from gymnasium>=0.27.0->shimmy) (4.4.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages (from gymnasium>=0.27.0->shimmy) (0.0.4)

# %%
import gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecNormalize
from tensorboardX import SummaryWriter
assim_rl_actionspace = np.linspace(0, 100, 21)


# Create an instance of your custom environment
env = ASACRLEnv(observations=obs, actions=actions, action_parameter="assim_sp", action_space=assim_rl_actionspace, num_intervals=len(assim_rl_actionspace) - 1)

# Wrap the environment with DummyVecEnv and VecNormalize
env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=True)

# ... [rest of the initialization remains unchanged]

# Exploration settings
epsilon = 1
EPSILON_DECAY = 0.99975
MIN_EPSILON = 0.001

# Stats settings
AGGREGATE_STATS_EVERY = 500
SAVE_MODEL_EVERY = 5000
MODEL_NAME = "AGCRL_ASSIM_CONT_SAC"
MIN_REWARD = -5000

# Create a SAC agent
# model = SAC("MlpPolicy", env, verbose=1, gradient_steps=-1, learning_rate=0.003, ent_coef=0)
model = PPO("MlpPolicy", env, 
            batch_size=1024,
            clip_range=0.15,
            verbose=1)

# Create a TensorBoard summary writer
writer = SummaryWriter(log_dir='PPO_Cont')

# Continuous training loop
ep_rewards = deque(maxlen=100)  # Stores the last 100 episode rewards
episode = 0

while True:
    episode += 1
    episode_reward = 0
    obs = env.reset()
    done = False

    while not done:
        if np.random.random() > epsilon:
            action, _ = model.predict(obs)
        else:
            action = env.action_space.sample()

        new_obs, reward, done, _ = env.step(action)

        episode_reward += reward
        obs = new_obs

        # Log information for TensorBoard (every few steps for efficiency)
        if episode % AGGREGATE_STATS_EVERY == 500:
            writer.add_scalar('Chosen Action', action, episode)
            writer.add_scalar('Observed State', np.mean(obs), episode)  # You can customize how you log the state
            writer.add_scalar('Received Reward', reward, episode)

    ep_rewards.append(episode_reward)

    if epsilon > MIN_EPSILON:
        epsilon *= EPSILON_DECAY
        epsilon = max(MIN_EPSILON, epsilon)

    if episode_reward >= MIN_REWARD and episode % SAVE_MODEL_EVERY == 100:
        model.save(f'{MODEL_NAME}__ep_{episode}__reward_{float(episode_reward):.2f}.model')

    # Update the model based on a larger number of timesteps
    model.learn(total_timesteps=1)  # Adjust the total_timesteps as needed

    # Log metrics for TensorBoard
    writer.add_scalar('Episode Reward', episode_reward, episode)
    writer.add_scalar('Epsilon', epsilon, episode)
    writer.add_scalar('Average Reward (last 100 eps)', np.mean(ep_rewards), episode)

    # # Termination condition (you can adjust this)
    # if len(ep_rewards) == 100 and np.mean(ep_rewards) > YOUR_DESIRED_REWARD_THRESHOLD:
    #     break

# Close the TensorBoard writer
writer.close()
# Out:
# /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2641 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2499 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2952 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2805 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3276 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2004 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3072 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3186 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3286 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3410 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3075 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3306 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2408 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3377 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2724 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2563 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2687 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3097 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3081 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2961 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3173 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2709 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2380 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3319 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3069 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2394 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3208 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3163 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2752 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2484 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2174 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2721 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2731 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2332 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2674 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2409 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3009 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2310 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2611 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2797 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2941 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2985 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3147 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2901 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3104 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3032 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2958 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3060 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3233 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2883 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2337 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2720 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2878 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2885 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2799 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2793 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3160 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2866 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2893 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2878 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2637 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2840 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2866 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2981 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3102 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2266 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2637 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2636 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3411 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3249 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2955 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3349 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2596 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2673 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3243 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2275 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2590 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2559 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2434 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2797 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3115 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3037 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2786 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2534 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2732 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3091 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2719 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2659 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2518 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2962 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2923 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2828 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2662 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2315 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2400 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2660 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2867 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3061 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2765 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3151 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3043 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3189 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2908 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2984 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2012 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2752 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2981 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2752 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3295 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2796 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3073 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2862 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2897 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2989 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3314 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2689 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2856 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2645 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2864 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3254 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2932 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2817 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2664 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2740 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2932 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2633 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2488 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2839 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2868 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3236 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2286 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1491 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2373 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2419 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2517 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2246 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2350 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2649 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2251 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2607 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2523 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2659 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2584 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2604 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2672 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2669 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2606 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2611 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2634 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2354 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3409 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2499 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3514 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3574 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2939 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2903 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2754 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3079 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3371 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2970 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3033 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3267 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3569 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3555 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2914 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2661 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2685 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3313 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3441 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3445 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3256 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2585 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2705 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3176 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3052 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3432 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2128 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3381 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2502 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3318 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2855 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2619 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3133 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3385 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3196 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2474 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3144 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3453 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3250 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3114 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3121 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3356 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2839 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2589 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3181 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2968 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2279 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3271 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2296 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3536 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3090 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3195 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2943 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2986 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3305 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3417 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2528 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3464 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3074 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3029 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3271 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2523 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2805 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2668 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2975 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2872 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3102 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3382 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2842 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2543 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2987 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3210 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3201 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3228 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3127 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3269 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3084 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# ...
# | time/              |      |
# |    fps             | 2487 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3184 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3152 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3108 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3090 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3182 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3213 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3099 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3162 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3518 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3160 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3114 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3178 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3154 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3159 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3123 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3130 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3048 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3480 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3439 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3448 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2928 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2743 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2678 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2555 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2875 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2301 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2282 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2340 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2223 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2056 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1966 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1441 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1368 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1069 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 768  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 670  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 776  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 800  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 910  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1236 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1310 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1159 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1272 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1226 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1195 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1217 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1268 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1280 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1240 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1238 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1192 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1186 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1236 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1128 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1275 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1266 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2293 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2704 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 77
#      74     model.save(f'{MODEL_NAME}__ep_{episode}__reward_{float(episode_reward):.2f}.model')
#      76 # Update the model based on a larger number of timesteps
# ---> 77 model.learn(total_timesteps=1)  # Adjust the total_timesteps as needed
#      79 # Log metrics for TensorBoard
#      80 writer.add_scalar('Episode Reward', episode_reward, episode)
#
# File ~/anaconda3/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:246, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     235 def learn(
#     236     self: SelfOnPolicyAlgorithm,
#     237     total_timesteps: int,
#    (...)
#     242     progress_bar: bool = False,
#     243 ) -> SelfOnPolicyAlgorithm:
#     244     iteration = 0
# --> 246     total_timesteps, callback = self._setup_learn(
#     247         total_timesteps,
#     248         callback,
#     249         reset_num_timesteps,
#     250         tb_log_name,
#     251         progress_bar,
#     252     )
#     254     callback.on_training_start(locals(), globals())
#     256     assert self.env is not None
#
# File ~/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/base_class.py:433, in BaseAlgorithm._setup_learn(self, total_timesteps, callback, reset_num_timesteps, tb_log_name, progress_bar)
#     431 # Configure logger's outputs if no logger was passed
#     432 if not self._custom_logger:
# --> 433     self._logger = utils.configure_logger(self.verbose, self.tensorboard_log, tb_log_name, reset_num_timesteps)
#     435 # Create eval callback if needed
#     436 callback = self._init_callback(callback, progress_bar)
#
# File ~/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/utils.py:213, in configure_logger(verbose, tensorboard_log, tb_log_name, reset_num_timesteps)
#     211 elif verbose == 0:
#     212     format_strings = [""]
# --> 213 return configure(save_path, format_strings=format_strings)
#
# File ~/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/logger.py:650, in configure(folder, format_strings)
#     648     folder = os.path.join(tempfile.gettempdir(), datetime.datetime.now().strftime("SB3-%Y-%m-%d-%H-%M-%S-%f"))
#     649 assert isinstance(folder, str)
# --> 650 os.makedirs(folder, exist_ok=True)
#     652 log_suffix = ""
#     653 if format_strings is None:
#
# File ~/anaconda3/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# OSError: [Errno 28] No space left on device: '/var/folders/vx/1m1l_7hj50l31_jjvmr4z0hw0000gn/T/SB3-2023-08-24-20-28-28-573953'
