# %%
import numpy as np
# import random
# random.seed(42)
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import os
from tqdm import tqdm
import time
import tensorflow as tf
import gym

# %%
# import numpy as np

class ASACRLEnv(gym.Env):
    def __init__(self,observations,actions,action_parameter,action_space):
        """initialise action space, observation space & load data"""
        self.action_parameter = action_parameter
        self.action_space = gym.spaces.Discrete(len(action_space))  # Use Discrete action space
        self.observations = observations
        self.actions = actions
        self.index=0
        self.teamindex=0
        obs_min = np.min(self.observations[self.teamindex]).values
        obs_max = np.max(self.observations[self.teamindex]).values

        self.observation_space = gym.spaces.Box(
            low=obs_min,
            high=obs_max,
            shape=self.observations[self.teamindex].iloc[0].shape,
            dtype=np.float32)
        self.curr_obs=self.observations[self.teamindex].iloc[self.index]
        self.next_obs=self.curr_obs=self.observations[self.teamindex].iloc[self.index+1]
        self.curr_reward=0
        self.ep_reward=0
        self.interval=action_space[1]-action_space[0]


    def step(self, action):
        self.reward = self.rewardfunc(action)
        self.ep_reward += self.reward
        self.index += 1
        cur_obs = self.curr_obs
        next_obs = self.next_obs
        done = False  # Set done to False by default
        if self.index >= len(self.observations[self.teamindex]) - 2:
            self.reset()
            done = True  # Set done to True when the episode is finished
            return self.curr_obs, self.reward, done, {}  # Return the additional info as an empty dictionary
        self.curr_obs = self.observations[self.teamindex].iloc[self.index]
        self.next_obs = self.curr_obs = self.observations[self.teamindex].iloc[self.index + 1]
        return self.curr_obs, self.reward, done, {}

    def reset(self):
        """
        set index to 0 and increment team index by 1 if greater than 4 go back to 0
        """
        self.teamindex+=1
        if self.teamindex>=5:
            self.teamindex=0
        self.index=0
        self.observation_space=self.observations[self.teamindex].iloc[0].shape
        self.curr_obs=self.observations[self.teamindex].iloc[self.index]
        self.next_obs=self.curr_obs=self.observations[self.teamindex].iloc[self.index+1]
        self.curr_reward=0
        self.ep_reward=0
        return self.curr_obs
    def rewardfunc(self, action):
        # estimated_action = self.estimate_closest_as(self.actions[self.teamindex][self.action_parameter][self.index])
        if action == self.estimate_closest_as(self.actions[self.teamindex][self.action_parameter][self.index]):
            return 100
        else:
            return -1 * abs(action - self.estimate_closest_as(self.actions[self.teamindex][self.action_parameter][self.index]))

        
#             return -1*abs(self.action_space[action]-self.actions[self.teamindex]["assim_sp"][self.index])

    def estimate_closest_as(self, value):
        try:
            closest_action_index = int(value / self.interval)
            closest_action_index = min(closest_action_index, self.action_space.n - 1)
        except:
            closest_action_index = self.action_space.n - 1
        return closest_action_index



    def resetinit(self):
        self.teamindex=0
        self.index=0
        self.observation_space=self.observations[self.teamindex].iloc[0].shape
        self.curr_obs=self.observations[self.teamindex].iloc[self.index]
        self.next_obs=self.curr_obs=self.observations[self.teamindex].iloc[self.index+1]
        self.curr_reward=0
        self.ep_reward=0
        return self.curr_obs

# %%
# env.action_space

# %%
with open('/Users/faymajidelhassan/Downloads/ASAC_2023/observations.pickle', 'rb') as handle:
    obs = pickle.load(handle)
with open('/Users/faymajidelhassan/Downloads/ASAC_2023/actions.pickle', 'rb') as handle:
    actions = pickle.load(handle)

# %%
assim_rl_actionspace=np.linspace(0,100,21)
discrete=list(range(len(assim_rl_actionspace)))

# %%
import gym
import numpy as np
from stable_baselines3 import PPO

# Create an instance of your custom environment
env = ASACRLEnv(obs, actions, "assim_sp", discrete)

# Create a PPO agent using the DummyVecEnv wrapper
from stable_baselines3.common.vec_env import DummyVecEnv
env = DummyVecEnv([lambda: env])
# Out:
# /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
import gym
import numpy as np
import torch
from tqdm import tqdm
from stable_baselines3 import PPO
from tensorboardX import SummaryWriter  # Import the SummaryWriter for TensorBoard

# Create an instance of your custom environment
# env = ASACRLEnv(obs, actions, "assim_sp", discrete)
# Environment settings
EPISODES = 1  # Number of episodes
# Exploration settings
epsilon = 1  # not a constant, going to be decayed
EPSILON_DECAY = 0.99975
MIN_EPSILON = 0.15

# Stats settings
AGGREGATE_STATS_EVERY = 500  # steps
SAVE_MODEL_EVERY = 5000
MODEL_NAME = "AGCRL_ASSIM_BIN"
MIN_REWARD = -5000


# Create a PPO agent
model = PPO("MlpPolicy", env, 
            batch_size=1024,
            clip_range=0.15,
            verbose=1)

# Create a TensorBoard summary writer
writer = SummaryWriter(log_dir='PPO_LOG52')


# Continuous training loop
ep_rewards = []
episode = 0
while True:
    episode += 1
    episode_reward = 0
    obs = env.reset()
    done = False

    while not done:
        if np.random.random() > epsilon:
            action, _ = model.predict(obs)
        else:
            action = env.action_space.sample()

        # Assuming action is a scalar value
        new_obs, reward, done, _ = env.step([action])

        episode_reward += reward
        obs = new_obs

        # Log information for TensorBoard
        writer.add_scalar('Chosen Action', action, episode)
        writer.add_scalar('Observed State', np.mean(obs), episode)  # You can customize how you log the state
        writer.add_scalar('Received Reward', reward, episode)

        if done:
            ep_rewards.append(episode_reward)

            if epsilon > MIN_EPSILON:
                epsilon *= EPSILON_DECAY
                epsilon = max(MIN_EPSILON, epsilon)

            if episode_reward >= MIN_REWARD and episode % SAVE_MODEL_EVERY == SAVE_MODEL_EVERY :
                model.save(f'models/{MODEL_NAME}__ep_{episode}__reward_{float(episode_reward):.2f}.model')

            model.learn(total_timesteps=1)

            # Log metrics for TensorBoard
            writer.add_scalar('Episode Reward', episode_reward, episode)
            writer.add_scalar('Epsilon', epsilon, episode)

# Close the TensorBoard writer (this line will never be reached in infinite loop)
writer.close()

# Plot results (same as before)
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(ep_rewards)
plt.xlabel('Episode')
plt.ylabel('Episode Reward')
plt.title('Episode Rewards')

plt.subplot(1, 2, 2)
plt.plot(acc_regret)
plt.xlabel('Episode')
plt.ylabel('Accumulated Regret')
plt.title('Accumulated Regret')

plt.tight_layout()
plt.show()
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 3460 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3519 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3605 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3613 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3464 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3448 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3687 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3638 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3129 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3631 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3572 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3724 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3622 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3713 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3600 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3458 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3622 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3610 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3462 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3631 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3685 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3696 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3638 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3834 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3449 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3568 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3553 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3836 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3604 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3513 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3333 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3536 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3635 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3746 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3702 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3650 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3795 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3499 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3976 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3382 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3728 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3431 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3716 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3714 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3685 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3674 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3657 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3721 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3597 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3800 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3763 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3602 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3927 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3661 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3567 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3990 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3744 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3832 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3777 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3645 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3752 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3859 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3710 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3775 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3750 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3598 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3740 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3829 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3870 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3765 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3715 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3851 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3554 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3753 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3694 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3794 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3739 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3706 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3880 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3724 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3682 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3828 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3716 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3794 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3823 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3708 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3864 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3736 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3788 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3561 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3706 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3795 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3760 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3153 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2429 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2308 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3237 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3781 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3614 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3382 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3405 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3490 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3417 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2805 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3503 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3379 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3566 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3592 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3531 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2563 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2806 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3590 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2528 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3587 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3330 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3004 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2434 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2997 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1871 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2859 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3420 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2793 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3693 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3583 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3205 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3771 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3760 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3424 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3751 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3827 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3622 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3774 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3565 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3628 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3824 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2985 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3517 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2204 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3698 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3404 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3505 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3501 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3546 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3390 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3718 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3390 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3442 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3613 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3414 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3772 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3791 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3384 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3824 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3657 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3536 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3830 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3628 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3738 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3277 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3691 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3800 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3806 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3699 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3936 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3805 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3737 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3830 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3819 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3813 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3788 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3345 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3850 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3694 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3876 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3709 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3746 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3821 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3668 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3230 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3785 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3773 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3771 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3951 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3769 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3611 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3178 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3151 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3269 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3627 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2468 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3288 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3345 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2537 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3320 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2934 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3281 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3279 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3221 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3148 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3104 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2491 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3259 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3215 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3349 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2433 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3653 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3598 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3899 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3152 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2613 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3284 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3492 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3502 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3199 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3639 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3126 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3454 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3562 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3335 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3631 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3730 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3703 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2676 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3377 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2752 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3436 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3440 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3733 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3682 |
# ...
# -----------------------------
# | time/              |      |
# |    fps             | 4069 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3665 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3829 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4308 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4024 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3730 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4127 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2974 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4273 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1637 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4243 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2892 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3443 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4214 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4049 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3513 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3800 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2947 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4219 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3639 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4222 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4162 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4174 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3856 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4077 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2193 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3515 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3265 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2203 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2315 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3618 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3764 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4114 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3840 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4041 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3669 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4095 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4250 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4172 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4180 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4153 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4209 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4151 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3640 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 4047 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3853 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2430 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 3188 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2808 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 2279 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1617 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 679  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 746  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1065 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1576 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1304 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 687  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1088 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1229 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1178 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/faymajidelhassan/anaconda3/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/tensorboardX/event_file_writer.py", line 208, in run
#     self._record_writer.write_event(data)
#   File "/Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/tensorboardX/event_file_writer.py", line 58, in write_event
#     return self._write_serialized_event(event.SerializeToString())
#   File "/Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/tensorboardX/event_file_writer.py", line 63, in _write_serialized_event
#     self._py_recordio_writer.write(event_str)
#   File "/Users/faymajidelhassan/anaconda3/lib/python3.10/site-packages/tensorboardX/record_writer.py", line 189, in write
#     w(data)
# OSError: [Errno 28] No space left on device
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 57
#      54 obs = new_obs
#      56 # Log information for TensorBoard
# ---> 57 writer.add_scalar('Chosen Action', action, episode)
#      58 writer.add_scalar('Observed State', np.mean(obs), episode)  # You can customize how you log the state
#      59 writer.add_scalar('Received Reward', reward, episode)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorboardX/writer.py:455, in SummaryWriter.add_scalar(self, tag, scalar_value, global_step, walltime, display_name, summary_description)
#     453     else:
#     454         raise TypeError("Input value: \"{}\" is not a scalar".format(scalar_value))
# --> 455 self._get_file_writer().add_summary(
#     456     scalar(tag, scalar_value, display_name, summary_description), global_step, walltime)
#     457 self._get_comet_logger().log_metric(tag, display_name, scalar_value, global_step)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorboardX/writer.py:145, in FileWriter.add_summary(self, summary, global_step, walltime)
#     133 """Adds a `Summary` protocol buffer to the event file.
#     134 This method wraps the provided summary in an `Event` protocol buffer
#     135 and adds it to the event file.
#    (...)
#     142     walltime (from time.time())
#     143 """
#     144 event = event_pb2.Event(summary=summary)
# --> 145 self.add_event(event, global_step, walltime)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorboardX/writer.py:130, in FileWriter.add_event(self, event, step, walltime)
#     126 if step is not None:
#     127     # Make sure step is converted from numpy or other formats
#     128     # since protobuf might not convert depending on version
#     129     event.step = int(step)
# --> 130 self.event_writer.add_event(event)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorboardX/event_file_writer.py:139, in EventFileWriter.add_event(self, event)
#     133 """Adds an event to the event file.
#     134
#     135 Args:
#     136   event: An `Event` protocol buffer.
#     137 """
#     138 if not self._closed:
# --> 139     self._event_queue.put(event)
#
# File ~/anaconda3/lib/python3.10/multiprocessing/queues.py:89, in Queue.put(self, obj, block, timeout)
#      87 if self._closed:
#      88     raise ValueError(f"Queue {self!r} is closed")
# ---> 89 if not self._sem.acquire(block, timeout):
#      90     raise Full
#      92 with self._notempty:
#
# KeyboardInterrupt:
